# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("house_train.csv")
df.head()
# Out:
#    ID  Location Paint_Color  Lot_Width  Lot_Depth  Year_Sold  Year_Built  \
# 0   1    Suburb       Green        134        NaN       2020        1990
# 1   2  Downtown       Green         76       93.0       2025        2019
# 2   3    Suburb      Yellow         91       83.0       2019        2003
# 3   4    Suburb       Green         26       21.0       2022        1995
# 4   5     Rural         Red        138       85.0       2017        1980
#
#    Living_Area  Num_Rooms      Price
# 0          813          6  1548800.0
# 1         3093          6  1974800.0
# 2         2845          3  2466950.0
# 3         1837          3   968700.0
# 4         4928          8  2570700.0

# %%
print(df[["Location","Paint_Color"]].nunique())
print(df[["Location"]].value_counts())
print(df["Paint_Color"].value_counts())
# Out:
# Location       3
# Paint_Color    4
# dtype: int64
# Location
# Suburb      982
# Rural       615
# Downtown    403
# Name: count, dtype: int64
# Paint_Color
# Red       537
# Yellow    530
# Green     475
# Blue      458
# Name: count, dtype: int64

# %%
#df['Location'].replace(['Suburb', 'Rural', 'Downtown'],
#                        [0, 1,2], inplace=True)
#df['Paint_Color'].replace(['Red', 'Yellow', 'Green', "Blue"],
#                        [0, 1,2,3], inplace=True)

# %%
df.head()
# Out:
#    ID  Location Paint_Color  Lot_Width  Lot_Depth  Year_Sold  Year_Built  \
# 0   1    Suburb       Green        134        NaN       2020        1990
# 1   2  Downtown       Green         76       93.0       2025        2019
# 2   3    Suburb      Yellow         91       83.0       2019        2003
# 3   4    Suburb       Green         26       21.0       2022        1995
# 4   5     Rural         Red        138       85.0       2017        1980
#
#    Living_Area  Num_Rooms      Price
# 0          813          6  1548800.0
# 1         3093          6  1974800.0
# 2         2845          3  2466950.0
# 3         1837          3   968700.0
# 4         4928          8  2570700.0

# %%
df.isna().sum()
# Out:
# ID               0
# Location         0
# Paint_Color      0
# Lot_Width        0
# Lot_Depth      279
# Year_Sold        0
# Year_Built       0
# Living_Area      0
# Num_Rooms        0
# Price            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
#lets checks pattrens

sns.boxplot(data=df, x= "Location", y = "Price")
# Out:
# <Axes: xlabel='Location', ylabel='Price'>

# %% [markdown]
# There is no major change in price between suburban, downtown or rural median is same, only outliers are more in suburbs

# %%
# let me remove outliers
df = df[df["Price"] < 5000000]

# %%
sns.boxplot(data=df, x= "Paint_Color", y = "Price")
# Out:
# <Axes: xlabel='Paint_Color', ylabel='Price'>

# %% [markdown]
# Same with colors, although Red has highest outlier

# %%
sns.scatterplot(data=df, x= "Lot_Depth", y = "Price")
# Out:
# <Axes: xlabel='Lot_Depth', ylabel='Price'>

# %% [markdown]
# There is no significant correlation although a slight positive correlation in some outliers

# %%
sns.scatterplot(data=df, x= "Lot_Width", y = "Price")
# Out:
# <Axes: xlabel='Lot_Width', ylabel='Price'>

# %% [markdown]
# There is no significant correlation although a slight positive correlation in some outliers

# %%
sns.scatterplot(data=df, x= "Year_Sold", y = "Price")
# Out:
# <Axes: xlabel='Year_Sold', ylabel='Price'>

# %% [markdown]
# some outliers are positive although no significant correlation

# %%
sns.scatterplot(data=df, x= "Year_Built", y = "Price")
# Out:
# <Axes: xlabel='Year_Built', ylabel='Price'>

# %% [markdown]
# No significant correlation

# %%
sns.scatterplot(data=df, x= "Living_Area", y = "Price")
# Out:
# <Axes: xlabel='Living_Area', ylabel='Price'>

# %% [markdown]
# Bit positive

# %%
sns.scatterplot(data=df, x= "Num_Rooms", y = "Price")
# Out:
# <Axes: xlabel='Num_Rooms', ylabel='Price'>

# %% [markdown]
# no correlation

# %%
df[[ "Lot_Width",
    "Lot_Depth",
    "Year_Sold",
    "Year_Built",
    "Living_Area",
    "Num_Rooms",
   "Price"]].corr()
# Out:
#              Lot_Width  Lot_Depth  Year_Sold  Year_Built  Living_Area  \
# Lot_Width     1.000000   0.035746   0.006147    0.031876    -0.015398
# Lot_Depth     0.035746   1.000000  -0.007057    0.028620    -0.009298
# Year_Sold     0.006147  -0.007057   1.000000    0.190974     0.031057
# Year_Built    0.031876   0.028620   0.190974    1.000000    -0.012702
# Living_Area  -0.015398  -0.009298   0.031057   -0.012702     1.000000
# Num_Rooms     0.013331   0.034470  -0.003154   -0.050051     0.010976
# Price         0.520420   0.495536   0.014344    0.095586     0.364679
#
#              Num_Rooms     Price
# Lot_Width     0.013331  0.520420
# Lot_Depth     0.034470  0.495536
# Year_Sold    -0.003154  0.014344
# Year_Built   -0.050051  0.095586
# Living_Area   0.010976  0.364679
# Num_Rooms     1.000000 -0.376643
# Price        -0.376643  1.000000

# %% [markdown]
# lets go with numerical correlation values, being lot_width, lot_depth, number of rooms and living area having higher correlation

# %%
df_clean = df.dropna()


features = [
    "Lot_Width",
    "Lot_Depth",
    "Living_Area",
    "Num_Rooms"]

target = "Price"

X = df_clean[features]

y = df_clean[target]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
df_test = pd.read_csv("house_test.csv")
df_test.head()
df_test.isna().sum()
# Out:
# ID             0
# Location       0
# Paint_Color    0
# Lot_Width      0
# Lot_Depth      0
# Year_Sold      0
# Year_Built     0
# Living_Area    0
# Num_Rooms      0
# dtype: int64

# %%
X_test = df_test[features]

# %%
y_pred = model.predict(X_test)
pd.DataFrame(y_pred)
# Out:
#                 0
# 0    2.384915e+06
# 1    2.089553e+06
# 2    7.046232e+05
# 3    2.271161e+06
# 4    2.361523e+06
# ..            ...
# 995  2.389007e+06
# 996  1.180173e+06
# 997  1.799812e+06
# 998  2.472920e+06
# 999  1.751173e+06
#
# [1000 rows x 1 columns]

# %%
df_test["Price"] = pd.DataFrame(y_pred)
df_test.head()
# Out:
#      ID  Location Paint_Color  Lot_Width  Lot_Depth  Year_Sold  Year_Built  \
# 0  2001     Rural       Green        106        131       2023        1980
# 1  2002     Rural       Green         98         23       2016        1984
# 2  2003  Downtown       Green         42         45       2020        2014
# 3  2004     Rural         Red        100         36       2018        1991
# 4  2005     Rural      Yellow         67        111       2021        2021
#
#    Living_Area  Num_Rooms         Price
# 0         1076          7  2.384915e+06
# 1         4828          2  2.089553e+06
# 2         1405          5  7.046232e+05
# 3         4853          4  2.271161e+06
# 4         3512          6  2.361523e+06

# %%
submission_df = df_test[["ID","Price"]]
submission_df.to_csv("house_predicted.csv", index=False)

# %%
verify_submission = pd.read_csv("house_predicted.csv")
verify_submission.head()
# Out:
#      ID         Price
# 0  2001  2.384915e+06
# 1  2002  2.089553e+06
# 2  2003  7.046232e+05
# 3  2004  2.271161e+06
# 4  2005  2.361523e+06

# %% [markdown]
# ![kaggle.png](attachment:3d7d3be4-f3c4-44bf-9d33-45dd8160777e.png)

# %% [markdown]
# Good start!!
